# %% [markdown]
# # 📊 Seaborn Visualization Notebook
# This notebook demonstrates basic data visualization techniques using the Seaborn library.
# We'll cover:
# - Loading datasets
# - Plotting different types of charts
# - Understanding relationships between variables

# %% [markdown]
# ## 📦 Importing Required Libraries

# %%
# Import seaborn for visualization and matplotlib for display
import seaborn as sns 
import pandas as pd

# %%
# Execute the code below
df=pd.read_csv("train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Execute the code below
sns.countplot(x="Embarked", data=df)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
# Execute the code below
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
# Import seaborn for visualization and matplotlib for display

import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %%
# Execute the code below
sns.histplot(x="Age", data=df,kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# ## 📦 Box Plot

# %% [markdown]
# ### 📦 What is a Box Plot?
# A **box plot** is a graphical representation of data that shows the distribution using minimum, first quartile (Q1), median, third quartile (Q3), and maximum. It helps identify **outliers** and **skewness**.

# %%
# Create a box plot to understand distribution and outliers
sns.boxplot(x="Age", data=df)
# Out:
# <Axes: xlabel='Age'>

# %%
# Create a box plot to understand distribution and outliers
sns.boxplot(x="Pclass",y="Age",hue="Sex",data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
# Create a box plot to understand distribution and outliers
sns.boxplot(x="Sex",y="Age",hue="Survived",data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
# Execute the code below
sns.distplot(df[df['Survived']==0]['Age'],hist=False)
sns.distplot(df[df['Survived']==1]['Age'],hist=False)
# Out:
# C:\Users\RAJ KUMAR RAWAT\AppData\Local\Temp\ipykernel_29712\455601345.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']==0]['Age'],hist=False)
# C:\Users\RAJ KUMAR RAWAT\AppData\Local\Temp\ipykernel_29712\455601345.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ## 🔥 Heatmap

# %% [markdown]
# ### 🔥 What is a Heatmap?
# A **heatmap** is a graphical representation of data where values are represented with color intensity. It's often used to show **correlation matrices** in datasets to understand relationships between variables.

# %%
# Create a heatmap to visualize correlations between numeric features

sns.heatmap(pd.crosstab(df['Pclass'],df['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
# Execute the code below
sns.pairplot(df)

# %%
# Execute the code below
sns.lineplot(x="Age",y="Fare",data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>
